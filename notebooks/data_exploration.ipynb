# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## Load data

# %%
# read data from google drive
from google.colab import drive
drive.mount('/content/drive')

customer_df = pd.read_csv("/content/drive/MyDrive/dataset/customer_data_dirty.csv")
geolocation_df = pd.read_csv("/content/drive/MyDrive/dataset/geolocation_dirty.csv")
order_item_df = pd.read_csv("/content/drive/MyDrive/dataset/order_item_dirty.csv")
order_payments_df = pd.read_csv("/content/drive/MyDrive/dataset/order_payment_dirty.csv")
order_reviews_df = pd.read_csv("/content/drive/MyDrive/dataset/order_review_dirty.csv")
orders_df = pd.read_csv("/content/drive/MyDrive/dataset/orders_dataset_dirty.csv")
product_category_name_df = pd.read_csv("/content/drive/MyDrive/dataset/product_category_dirty.csv")
products_df = pd.read_csv("/content/drive/MyDrive/dataset/products_dirty.csv")
seller_df = pd.read_csv("/content/drive/MyDrive/dataset/seller_dirty.csv")

# customer_df = pd.read_csv("../dataset/customer_data_dirty.csv")
# geolocation_df = pd.read_csv("../dataset/geolocation_dirty.csv")
# order_item_df = pd.read_csv("../dataset/order_item_dirty.csv")
# order_payments_df = pd.read_csv("../dataset/order_payment_dirty.csv")
# order_reviews_df = pd.read_csv("../dataset/order_review_dirty.csv")
# orders_df = pd.read_csv("../dataset/orders_dataset_dirty.csv")
# product_category_name_df = pd.read_csv("../dataset/product_category_dirty.csv")
# products_df = pd.read_csv("../dataset/products_dirty.csv")
# seller_df = pd.read_csv("../dataset/seller_dirty.csv")
# Out:
# Mounted at /content/drive

# %%
print("Customer Data:")
display(customer_df.head())

print("Geolocation Data:")
display(geolocation_df.head())

print("order item Data:")
display(order_item_df.head())

print("order payment Data:")
display(order_payments_df.head())

print("orders Data:")
display(orders_df.head())
# Out:
# Customer Data:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad                               NaN
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                   14409.0                 franca             SP
# 1                    9790.0  sao bernardo do campo             SP
# 2                    1151.0              sao paulo             SP
# 3                    8775.0        mogi das cruzes             SP
# 4                   13056.0               campinas             SP
# Geolocation Data:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# ...

# %% [markdown]
# ## Merging Data

# %% [markdown]
# Merge data `customer_df` with `orders_df`

# %%
# customer_orders_df = pd.merge(customer_df, orders_df, on="customer_id", how="inner")

# # save data to csv
# customer_orders_df.to_csv("../dataset/customer_orders.csv", index=False)

# %%
# customer_orders_df = pd.read_csv("../dataset/customer_orders.csv")

# %%
customer_orders_df = pd.read_csv("/content/drive/MyDrive/dataset/customer_orders.csv")

# %%
customer_orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25591612 entries, 0 to 25591611
# Data columns (total 12 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   customer_id                    object
#  1   customer_unique_id             object
#  2   customer_zip_code_prefix       float64
#  3   customer_city                  object
#  4   customer_state                 object
#  5   order_id                       object
#  6   order_status                   object
#  7   order_purchase_timestamp       object
#  8   order_approved_at              object
#  9   order_delivered_carrier_date   object
#  10  order_delivered_customer_date  object
#  11  order_estimated_delivery_date  object
# dtypes: float64(1), object(11)
# memory usage: 2.3+ GB

# %%
customer_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad                               NaN
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                   14409.0                 franca             SP
# 1                    9790.0  sao bernardo do campo             SP
# 2                    1151.0              sao paulo             SP
# 3                    8775.0        mogi das cruzes             SP
# 4                   13056.0               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
# prompt: buatkan script untuk menghapus baris data di variable customer_orders_df menjadi hanya sebanyak 70.000 data saja dengan menggunakan metode drop

# Drop rows to limit the DataFrame to 70,000 rows
customer_orders_df = customer_orders_df.head(70000)

# Display info to verify the change
customer_orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    476 non-null    object
#  1   customer_unique_id             54893 non-null  object
#  2   customer_zip_code_prefix       69977 non-null  float64
#  3   customer_city                  69985 non-null  object
#  4   customer_state                 65817 non-null  object
#  5   order_id                       66488 non-null  object
#  6   order_status                   66359 non-null  object
#  7   order_purchase_timestamp       66752 non-null  object
#  8   order_approved_at              65961 non-null  object
#  9   order_delivered_carrier_date   64897 non-null  object
#  10  order_delivered_customer_date  64263 non-null  object
#  11  order_estimated_delivery_date  66561 non-null  object
# ...
